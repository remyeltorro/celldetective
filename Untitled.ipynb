# %%
from celldetective import track
from celldetective.tracking import extract_objects_and_features
from tifffile import imread
from glob import glob
from natsort import natsorted
import numpy as np

# %%
stack = imread("/home/limozin/Documents/Experiments/MinimumAdhesion/W1/100/movie/Aligned_Normed_13-Pos_000_000-1.tif")
labels = np.array([imread(f) for f in natsorted(glob("/home/limozin/Documents/Experiments/MinimumAdhesion/W1/100/labels_effectors/*.tif"))])
stack = np.moveaxis(stack, 1, -1)
stack.shape
# Out:
# (50, 1002, 1004, 2)

# %%
track(labels, None, stack=stack, spatial_calibration=1, features=['area', 'intensity_mean'], channel_names=['brightfield_channel', 'adhesion_channel'],
	  haralick_options=None, return_napari_data=False, view_on_napari=True, mask_timepoints=None, mask_channels=['brightfield_channel'],
	)
# Out:
# Using cell configuration from /home/limozin/.cache/btrack-examples/examples/cell_config.json.
# frame: 100%|████████████████████████████████████| 50/50 [00:01<00:00, 48.40it/s]
# [INFO][2023/07/25 09:40:25 AM] Objects are of type: <class 'pandas.core.frame.DataFrame'>
# [INFO][2023/07/25 09:40:25 AM] Loaded btrack: /home/limozin/anaconda3/lib/python3.11/site-packages/btrack/libs/libtracker.so
# [INFO][2023/07/25 09:40:25 AM] Starting BayesianTracker session
# [INFO][2023/07/25 09:40:25 AM] Loading configuration file: /home/limozin/.cache/btrack-examples/examples/cell_config.json
# [INFO][2023/07/25 09:40:25 AM] Objects are of type: <class 'list'>
# [INFO][2023/07/25 09:40:25 AM] Starting tracking...
# [INFO][2023/07/25 09:40:25 AM] Update using: ['VISUAL', 'MOTION']
# [INFO][2023/07/25 09:40:25 AM] Tracking objects in frames 0 to 50 (of 50)...
# [INFO][2023/07/25 09:40:25 AM]  - Timing (Bayesian updates: 6.53ms, Linking: 0.65ms)
# [INFO][2023/07/25 09:40:25 AM]  - Probabilities (Link: 1.00000, Lost: 1.00000)
# [INFO][2023/07/25 09:40:25 AM] SUCCESS.
# [INFO][2023/07/25 09:40:25 AM]  - Found 754 tracks in 50 frames (in 0.0s)
# [INFO][2023/07/25 09:40:25 AM]  - Inserted 336 dummy objects to fill tracking gaps
# [INFO][2023/07/25 09:40:25 AM] Loading hypothesis model: cell_hypothesis
# [INFO][2023/07/25 09:40:25 AM] Calculating hypotheses (relax: True)...
# [INFO][2023/07/25 09:40:25 AM] Setting up constraints matrix for global optimisation...
# [INFO][2023/07/25 09:40:25 AM] Using GLPK options: {'tm_lim': 120000}...
# [INFO][2023/07/25 09:40:25 AM] Optimizing...
# [INFO][2023/07/25 09:40:25 AM] Optimization complete. (Solution: optimal)
# [INFO][2023/07/25 09:40:25 AM]  - Fates.FALSE_POSITIVE: 290 (of 754)
# [INFO][2023/07/25 09:40:25 AM]  - Fates.LINK: 123 (of 246)
# [INFO][2023/07/25 09:40:25 AM]  - Fates.DIVIDE: 21 (of 67)
# [INFO][2023/07/25 09:40:25 AM]  - Fates.INITIALIZE_BORDER: 28 (of 55)
# [INFO][2023/07/25 09:40:25 AM]  - Fates.INITIALIZE_FRONT: 58 (of 72)
# [INFO][2023/07/25 09:40:25 AM]  - Fates.INITIALIZE_LAZY: 213 (of 627)
# [INFO][2023/07/25 09:40:25 AM]  - Fates.TERMINATE_BORDER: 20 (of 44)
# [INFO][2023/07/25 09:40:25 AM]  - Fates.TERMINATE_BACK: 241 (of 311)
# [INFO][2023/07/25 09:40:25 AM]  - Fates.TERMINATE_LAZY: 59 (of 399)
# [INFO][2023/07/25 09:40:25 AM]  - TOTAL: 2575 hypotheses
# [INFO][2023/07/25 09:40:25 AM] Completed optimization with 631 tracks
# [INFO][2023/07/25 09:40:25 AM] Ending BayesianTracker session
# GLPK Integer Optimizer 5.0
# 3016 rows, 2575 columns, 3709 non-zeros
# 2575 integer variables, all of which are binary
# Preprocessing...
# 1508 rows, 2575 columns, 3709 non-zeros
# 2575 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 1508
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 1508 rows, 2575 columns, 3709 non-zeros
# *     0: obj =   7.178866932e+03 inf =   0.000e+00 (721)
# *   689: obj =   3.333018514e+03 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   689: mip =     not found yet >=              -inf        (1; 0)
# +   692: >>>>>   3.333465082e+03 >=   3.333465082e+03   0.0% (3; 0)
# +   692: mip =   3.333465082e+03 >=     tree is empty   0.0% (0; 5)
# INTEGER OPTIMAL SOLUTION FOUND
# 100%|███████████████████████████████████████████| 50/50 [00:11<00:00,  4.37it/s]
#       TRACK_ID  FRAME  POSITION_Y  POSITION_X   t  state  generation  root  \
# 0          1.0    0.0  787.196721  500.590164   0      5           0     1
# 1          1.0    1.0  804.147727  494.231061   1      5           0     1
# 2          2.0    0.0  625.540323  368.161290   0      5           0     2
# 3          2.0    1.0  625.589147  368.255814   1      5           0     2
# 4          2.0    2.0  626.074324  368.270270   2      5           0     2
# ...        ...    ...         ...         ...  ..    ...         ...   ...
# 6999     749.0   49.0  383.007299  766.193431  49      5           0   749
# 7000     751.0   49.0  422.311688   11.090909  49      5           1   588
# 7001     752.0   49.0  458.309859   17.549296  49      5           1   588
# 7002     753.0   49.0  287.382353  433.941176  49      5           0   753
# 7003     754.0   49.0  348.224490  663.918367  49      5           0   754
#
#       parent   area  adhesion_channel_mean  class_id
# 0          1   61.0               1.179074      35.0
# 1          1  264.0               0.992630      41.0
# 2          2  124.0               0.939642      24.0
# 3          2  129.0               0.943636      30.0
# 4          2  148.0               0.924989      29.0
# ...      ...    ...                    ...       ...
# 6999     749  548.0               1.146974      92.0
# 7000     588   77.0               0.940509     105.0
# 7001     588   71.0               1.003765     115.0
# 7002     753   34.0               0.945836      74.0
# 7003     754   49.0               0.992208      87.0
#
# [7004 rows x 12 columns]

# %%
mask_channels = ['brightfield']
cols_to_drop = []
for mc in mask_channels:
    columns = test.columns
    col_contains = [mc in c for c in columns]
    to_remove = np.array(columns)[np.array(col_contains)]
    cols_to_drop.extend(to_remove)
if len(cols_to_drop)>0:
    test = test.drop(cols_to_drop, axis=1)
display(test)

# %%
from btrack.datasets import cell_config

cell_config()

# %%
from celldetective.tracking import interpolate_nan_properties, interpolate_per_track
import pandas as pd
import numpy as np

x = [0,1,5,2,5,4,5]
y = [5,1,4,1,1,2,6]
tid = [1,1,1,2,2,2,2]
t = [0,3,4,0,1,5,7]
f = [0,np.nan,10,np.nan,1,5,np.nan]

df = pd.DataFrame(np.moveaxis([tid,x,y,t,f],0,-1), columns=['tid','x','y','t','f'])
df = df.groupby('tid',group_keys=False).apply(interpolate_per_track)

df
# Out:
#    tid    x    y    t     f
# 0  1.0  0.0  5.0  0.0   0.0
# 1  1.0  1.0  1.0  3.0   5.0
# 2  1.0  5.0  4.0  4.0  10.0
# 3  2.0  2.0  1.0  0.0   1.0
# 4  2.0  5.0  1.0  1.0   1.0
# 5  2.0  4.0  2.0  5.0   5.0
# 6  2.0  5.0  6.0  7.0   5.0
